# %% [markdown]
# <h1 style="text-align:center"> Drexel University </h1>
# <h2 style = "text-align:center"> College of Computing and Informatics</h2>
# <h2 style = "text-align:center">INFO 371: Data Mining Applications</h2>
# <h3 style = "text-align:center">Assignment 4</h3>
# <div style="text-align:center; border-style:solid; padding: 10px">
# <div style="font-weight:bold">Due Date: end of the last week</div>
# This assignment counts for 15% of the final grade
# </div>
#
# ## **DON'T FORGET TO PUT YOUR NAME BELOW**
#
# ### **NAME**:
# Haoran Zhao
#
# ### A. What to Hand In
#
# 1. A completed this Jupyter notebook.
# 2. Any data files and multimedia used in the assignment.
#
# ### B. How to Hand In
#
# Submit your files through the course website in the Blackboard Learn system.
#
# ### C. When to Hand In
#
# 1. Submit your assignment no later than 11:59pm in the due date.
# 2. There will be a 10% (absolute value) deduction for each day of lateness, to a maximum of 3 days; assignments will not be accepted beyond that point. Missing work will earn a zero grade.
#
# ### D. Answer the following questions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# # Collecting the Data
# In this assignment you will work on a Kaggle data set for market analysis. The data set is available at Kaggle.com: https://www.kaggle.com/sulmansarwar/transactions-from-a-bakery
# * Download the CSV data from either the above Kaggle link or the course shell as BreadBasket_DMS.csv

# %% [markdown]
# ## Question 1 [5 points]: Upload the data and open it as a DataFrame. Show the columns, first 5 rows, and some descriptive statistics.

# %%
from google.colab import drive
drive.mount("/content/drive")
file = "/content/drive/MyDrive/Colab Notebooks/BreadBasket_DMS.csv"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv(file, parse_dates= ['Date'])

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Transaction', 'Item'], dtype='object')

# %%
df.head()
# Out:
#         Date      Time  Transaction           Item
# 0 2016-10-30  09:58:11            1          Bread
# 1 2016-10-30  10:05:34            2   Scandinavian
# 2 2016-10-30  10:05:34            2   Scandinavian
# 3 2016-10-30  10:07:57            3  Hot chocolate
# 4 2016-10-30  10:07:57            3            Jam

# %%
df.shape
# Out:
# (21293, 4)

# %%
df.describe()
# Out:
#         Transaction
# count  21293.000000
# mean    4951.990889
# std     2787.758400
# min        1.000000
# 25%     2548.000000
# 50%     5067.000000
# 75%     7329.000000
# max     9684.000000

# %%
df.tail()
# Out:
#             Date      Time  Transaction       Item
# 21288 2017-04-09  14:32:58         9682     Coffee
# 21289 2017-04-09  14:32:58         9682        Tea
# 21290 2017-04-09  14:57:06         9683     Coffee
# 21291 2017-04-09  14:57:06         9683     Pastry
# 21292 2017-04-09  15:04:24         9684  Smoothies

# %% [markdown]
# ## Question 2 [10 points]: Add a column 'count' with all values=1.

# %%
df['count'] = 1

# %%
df
# Out:
#             Date      Time  Transaction           Item  count
# 0     2016-10-30  09:58:11            1          Bread      1
# 1     2016-10-30  10:05:34            2   Scandinavian      1
# 2     2016-10-30  10:05:34            2   Scandinavian      1
# 3     2016-10-30  10:07:57            3  Hot chocolate      1
# 4     2016-10-30  10:07:57            3            Jam      1
# ...          ...       ...          ...            ...    ...
# 21288 2017-04-09  14:32:58         9682         Coffee      1
# 21289 2017-04-09  14:32:58         9682            Tea      1
# 21290 2017-04-09  14:57:06         9683         Coffee      1
# 21291 2017-04-09  14:57:06         9683         Pastry      1
# 21292 2017-04-09  15:04:24         9684      Smoothies      1
#
# [21293 rows x 5 columns]

# %% [markdown]
# ## Question 3 [25 points]: Convert the data to transactional format.
# 1.	We are interested in miming association rules among the items.
# 2.	In this task, you are asked to convert the two columns ‘Transaction’ and ‘Item’ to a format such that each row is a transaction and the columns are the items.
# 3.	Name the new data file as BreadBasket_DMS_pivot.csv. The values of the new data set represent the counts of an item (column) in a transaction (row).
# 4. You can use Excel to create a pivot table for the values under the two columns ‘Transaction’ and ‘Item’.
# 5. Or you can write any programs such as using Python to create the data table. *Hint*: Pandas has a method pivot_table() for creating pivot table.
# ```
# pd.pivot_table(df, values='count', index='Transaction', columns='Item', aggfunc='sum')
# ```

# %%
pivot_df = pd.pivot_table(df, values='count', index='Transaction', columns='Item', aggfunc='sum')

# %%
pivot_df
# Out:
# Item         Adjustment  ...  Victorian Sponge
# Transaction              ...
# 1                   NaN  ...               NaN
# 2                   NaN  ...               NaN
# 3                   NaN  ...               NaN
# 4                   NaN  ...               NaN
# 5                   NaN  ...               NaN
# ...                 ...  ...               ...
# 9680                NaN  ...               NaN
# 9681                NaN  ...               NaN
# 9682                NaN  ...               NaN
# 9683                NaN  ...               NaN
# 9684                NaN  ...               NaN
#
# [9531 rows x 95 columns]

# %%
pivot_df.to_csv('BreadBasket_DMS_pivot.csv')

# %% [markdown]
# ## Question 4 [20 points]: Load BreadBasket_DMS_pivot.csv as a DataFrame. Replace NaN values with 0. Make a DataFrame by replacing any values equal to or greater than 1 with True and other values with False.

# %%
BreadBasket_DMS = pd.read_csv('BreadBasket_DMS_pivot.csv', index_col='Transaction')
BreadBasket_DMS.columns.name = 'Item'

# %%
BreadBasket_DMS.head()
# Out:
# Item         Adjustment  ...  Victorian Sponge
# Transaction              ...
# 1                   NaN  ...               NaN
# 2                   NaN  ...               NaN
# 3                   NaN  ...               NaN
# 4                   NaN  ...               NaN
# 5                   NaN  ...               NaN
#
# [5 rows x 95 columns]

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Transaction', 'Item', 'count'], dtype='object')

# %%
df.Transaction.nunique(), df.Item.nunique()
# Out:
# (9531, 95)

# %%
BreadBasket_DMS.fillna(value = 0, inplace = True)
BreadBasket_DMS.replace({0: False}, inplace=True)

# %%
BreadBasket_DMS
# Out:
# Item        Adjustment Afternoon with the baker  ... Vegan mincepie Victorian Sponge
# Transaction                                      ...
# 1                False                    False  ...          False            False
# 2                False                    False  ...          False            False
# 3                False                    False  ...          False            False
# 4                False                    False  ...          False            False
# 5                False                    False  ...          False            False
# ...                ...                      ...  ...            ...              ...
# 9680             False                    False  ...          False            False
# 9681             False                    False  ...          False            False
# 9682             False                    False  ...          False            False
# ...

# %%
BreadBasket_DMS[BreadBasket_DMS != 0] = True

# %%
BreadBasket_DMS
# Out:
# Item        Adjustment Afternoon with the baker  ... Vegan mincepie Victorian Sponge
# Transaction                                      ...
# 1                False                    False  ...          False            False
# 2                False                    False  ...          False            False
# 3                False                    False  ...          False            False
# 4                False                    False  ...          False            False
# 5                False                    False  ...          False            False
# ...                ...                      ...  ...            ...              ...
# 9680             False                    False  ...          False            False
# 9681             False                    False  ...          False            False
# 9682             False                    False  ...          False            False
# ...

# %% [markdown]
# ## Question 5 [40 points]: Mining association rules using the API in the Mlxtend package.
# ```
# freq_items= apriori(transactional_data, min_support=xx, use_colnames=True)
# ```
# ```
# association_rules(freq_items, metric='confidence', min_threshold=xx)
# ```
#
# Test different values on the 'min_support' and 'min_threshold' parameters until you find some rules. With what values can you find some rules and why? Do you find any interesting association rules from the Bread Basket Data? Explain.

# %% [markdown]
# ## The first question

# %% [markdown]
# If we fix the min_threshold, and as we increase the value of min_support, the associated products become less and less.
# \
# If we fix the min_support, and as we increase the value of min_threshold, the associated products also become less and less.\
# So, the larger the values of min_support and min_threshold, the fewer the number of associated prodcuts we could find through association rules.

# %% [markdown]
# ## The secend question

# %% [markdown]
# In the Bread_Basket dataset, using different values of min_threshold and min_support, we could get different arrociation rules. However, I find there is a common thing when we apply Apriori rules which is Coffee always appear as a consequent. Antecedents can be Cake or Pastry or Bread(Some common food we buy in bakery), but Coffee always appears as the consequent.

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.01, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.3)
# Out:
#          antecedents consequents  ...  leverage  conviction
# 0        (Alfajores)    (Coffee)  ...  0.002368    1.142861
# 1           (Pastry)     (Bread)  ...  0.001172    1.020731
# 2          (Brownie)    (Coffee)  ...  0.000624    1.030799
# 3             (Cake)    (Coffee)  ...  0.005350    1.109667
# 4          (Cookies)    (Coffee)  ...  0.002343    1.090053
# 5    (Hot chocolate)    (Coffee)  ...  0.001863    1.065276
# 6            (Juice)    (Coffee)  ...  0.002266    1.127031
# 7        (Medialuna)    (Coffee)  ...  0.005779    1.218561
# 8           (Muffin)    (Coffee)  ...  0.000532    1.027260
# 9             (NONE)    (Coffee)  ...  0.004539    1.122908
# 10          (Pastry)    (Coffee)  ...  0.006590    1.172079
# 11        (Sandwich)    (Coffee)  ...  0.004086    1.122468
# 12           (Scone)    (Coffee)  ...  0.001642    1.100310
# 13            (Soup)    (Coffee)  ... -0.000512    0.972293
# 14  (Spanish Brunch)    (Coffee)  ...  0.002233    1.308493
# ...

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.03, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.3)
# Out:
#    antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0       (Cake)    (Coffee)            0.103137  ...  1.109196  0.005350    1.109667
# 1  (Medialuna)    (Coffee)            0.061379  ...  1.198175  0.005779    1.218561
# 2       (NONE)    (Coffee)            0.079005  ...  1.120938  0.004539    1.122908
# 3     (Pastry)    (Coffee)            0.085510  ...  1.162216  0.006590    1.172079
# 4   (Sandwich)    (Coffee)            0.071346  ...  1.120551  0.004086    1.122468
# 5        (Tea)    (Coffee)            0.141643  ...  0.735936 -0.017769    0.807107
#
# [6 rows x 9 columns]

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.05, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.3)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0      (Cake)    (Coffee)            0.103137  ...  1.109196   0.00535    1.109667
#
# [1 rows x 9 columns]

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.06, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.3)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.04, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.1)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0     (Bread)    (Coffee)            0.324940  ...  0.579069 -0.064980    0.724131
# 1    (Coffee)     (Bread)            0.475081  ...  0.579069 -0.064980    0.831522
# 2      (Cake)    (Coffee)            0.103137  ...  1.109196  0.005350    1.109667
# 3    (Coffee)      (Cake)            0.475081  ...  1.109196  0.005350    1.012717
# 4      (NONE)    (Coffee)            0.079005  ...  1.120938  0.004539    1.122908
# 5    (Pastry)    (Coffee)            0.085510  ...  1.162216  0.006590    1.172079
# 6    (Coffee)       (Tea)            0.475081  ...  0.735936 -0.017769    0.958245
# 7       (Tea)    (Coffee)            0.141643  ...  0.735936 -0.017769    0.807107
#
# [8 rows x 9 columns]

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.04, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.2)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0     (Bread)    (Coffee)            0.324940  ...  0.579069 -0.064980    0.724131
# 1      (Cake)    (Coffee)            0.103137  ...  1.109196  0.005350    1.109667
# 2      (NONE)    (Coffee)            0.079005  ...  1.120938  0.004539    1.122908
# 3    (Pastry)    (Coffee)            0.085510  ...  1.162216  0.006590    1.172079
# 4       (Tea)    (Coffee)            0.141643  ...  0.735936 -0.017769    0.807107
#
# [5 rows x 9 columns]

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.04, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.3)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0      (Cake)    (Coffee)            0.103137  ...  1.109196  0.005350    1.109667
# 1      (NONE)    (Coffee)            0.079005  ...  1.120938  0.004539    1.122908
# 2    (Pastry)    (Coffee)            0.085510  ...  1.162216  0.006590    1.172079
# 3       (Tea)    (Coffee)            0.141643  ...  0.735936 -0.017769    0.807107
#
# [4 rows x 9 columns]

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.04, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.4)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0      (Cake)    (Coffee)            0.103137  ...  1.109196  0.005350    1.109667
# 1      (NONE)    (Coffee)            0.079005  ...  1.120938  0.004539    1.122908
# 2    (Pastry)    (Coffee)            0.085510  ...  1.162216  0.006590    1.172079
#
# [3 rows x 9 columns]

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.04, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.5)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0      (Cake)    (Coffee)            0.103137  ...  1.109196  0.005350    1.109667
# 1      (NONE)    (Coffee)            0.079005  ...  1.120938  0.004539    1.122908
# 2    (Pastry)    (Coffee)            0.085510  ...  1.162216  0.006590    1.172079
#
# [3 rows x 9 columns]

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.04, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.55)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0    (Pastry)    (Coffee)             0.08551  ...  1.162216   0.00659    1.172079
#
# [1 rows x 9 columns]

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.04, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.6)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction]
# Index: []

# %%
freq_items= apriori(BreadBasket_DMS, min_support=0.06, use_colnames=True)
association_rules(freq_items, metric='confidence', min_threshold=0.25)
# Out:
#   antecedents consequents  antecedent support  ...      lift  leverage  conviction
# 0     (Bread)    (Coffee)             0.32494  ...  0.579069  -0.06498    0.724131
#
# [1 rows x 9 columns]
